# %%
import matplotlib
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from collections import defaultdict
import sys ; sys.path.insert(0, "../")

matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['lines.linewidth'] = 3
matplotlib.rcParams['lines.markersize'] = 10
matplotlib.rcParams['ps.fonttype'] = 42
ALPHA = 0.6
font = {'weight': 'normal', 'size': 16}
matplotlib.rc('font', **font)
plt.style.use('dark_background')

# %%
f = open("../../data/Output_Other211_2021-09-08_06-33-36.csv", 'r')
lines = f.readlines()
f.close()

# %%
data = []

print(lines[0])
for line in lines[1:]:
    temp = list(map(float, line.strip().split(",")))
    data.append([
        temp[0], # timestamp
        temp[4], # current-speed
        temp[5], # current-acceleration
        temp[6], # target-acceleration
        temp[8], # time-gap
        temp[9], # distance-gap
        temp[-3] # takeover-count
    ])

data = np.array(data)
# Out:
# timestamp, controller, weather, vehicle, current-speed, current-acceleration, target_acceleration, lead-speed,time-gap, distance-gap, position-x, position-y, position-z, takeover-count, takeover-period, takeover-flag

# %%
distance_gap = data[:, -2]
plt.scatter(list(range(len(data))), distance_gap)
print(min(distance_gap), max(distance_gap))

sns.displot(distance_gap)
# Out:
# 2.086621 271.5607
